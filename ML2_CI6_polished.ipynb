# %% [markdown]
# ## Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.patches import FancyArrowPatch
import matplotlib.cm as cm
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, adjusted_rand_score, calinski_harabasz_score, silhouette_samples, pairwise_distances
# from sklearn_extra.cluster import KMedoids
# from kmodes.kprototypes import  KPrototypes
# from kmodes.kmodes import KModes  # For K-Modes

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
import plotly.express as px

# %% [markdown]
# ## Data

# %%
data = pd.read_csv("PhiUSIIL_Phishing_URL_Dataset.csv")

# %%
data = data.drop(columns=['FILENAME'])

# %% [markdown]
# ## Data Cleaning

# %%
label_encoder = LabelEncoder()

# %%
for column in data.select_dtypes(include=['object']).columns:
    data[column] = label_encoder.fit_transform(data[column])

# %% [markdown]
# ## EDA

# %%
print(data.describe())
# Out:
#                URL    URLLength       Domain  DomainLength   IsDomainIP  \
# count  4486.000000  4486.000000  4486.000000   4486.000000  4486.000000
# mean   2242.500000    30.853767  2205.345742     20.780874     0.001560
# std    1295.140983    20.904945  1289.242044      7.799517     0.039476
# min       0.000000    13.000000     0.000000      4.000000     0.000000
# 25%    1121.250000    23.000000  1080.250000     16.000000     0.000000
# 50%    2242.500000    27.000000  2201.500000     19.000000     0.000000
# 75%    3363.750000    32.000000  3322.750000     24.000000     0.000000
# max    4485.000000   472.000000  4444.000000     86.000000     1.000000
#
#                TLD  URLSimilarityIndex  CharContinuationRate  \
# count  4486.000000         4486.000000           4486.000000
# mean     70.543469           84.625886              0.873251
# std      47.713744           25.175642              0.198694
# min       0.000000            1.727385              0.142857
# 25%      40.000000           69.798334              0.750000
# 50%      40.000000          100.000000              1.000000
# 75%     121.000000          100.000000              1.000000
# max     189.000000          100.000000              1.000000
#
#        TLDLegitimateProb  URLCharProb  ...          Pay       Crypto  \
# count        4486.000000  4486.000000  ...  4486.000000  4486.000000
# mean            0.265679     0.057104  ...     0.258359     0.027196
# std             0.250534     0.009997  ...     0.437781     0.162671
# min             0.000000     0.001223  ...     0.000000     0.000000
# 25%             0.009442     0.052935  ...     0.000000     0.000000
# 50%             0.079963     0.058974  ...     0.000000     0.000000
# 75%             0.522907     0.063563  ...     1.000000     0.000000
# max             0.522907     0.082457  ...     1.000000     1.000000
#
#        HasCopyrightInfo    NoOfImage      NoOfCSS       NoOfJS  NoOfSelfRef  \
# count       4486.000000  4486.000000  4486.000000  4486.000000  4485.000000
# mean           0.551494    31.806509     7.077129    12.505350    77.309030
# std            0.497397    89.027011    11.215447    26.619225   123.709857
# min            0.000000     0.000000     0.000000     0.000000     0.000000
# 25%            0.000000     0.000000     0.000000     0.000000     0.000000
# 50%            1.000000    14.000000     3.000000     8.000000    36.000000
# 75%            1.000000    34.000000     9.000000    17.000000   106.000000
# max            1.000000  2326.000000   115.000000  1326.000000  1871.000000
#
#        NoOfEmptyRef  NoOfExternalRef        label
# count   4485.000000      4485.000000  4485.000000
# mean       2.650390        57.664883     0.669565
# std       12.380507       106.484681     0.470422
# min        0.000000         0.000000     0.000000
# 25%        0.000000         1.000000     0.000000
# 50%        0.000000        18.000000     1.000000
# 75%        1.000000        71.000000     1.000000
# max      475.000000      1873.000000     1.000000
#
# [8 rows x 55 columns]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4486 entries, 0 to 4485
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   URL                         4486 non-null   int64
#  1   URLLength                   4486 non-null   int64
#  2   Domain                      4486 non-null   int64
#  3   DomainLength                4486 non-null   int64
#  4   IsDomainIP                  4486 non-null   int64
#  5   TLD                         4486 non-null   int64
#  6   URLSimilarityIndex          4486 non-null   float64
#  7   CharContinuationRate        4486 non-null   float64
#  8   TLDLegitimateProb           4486 non-null   float64
#  9   URLCharProb                 4486 non-null   float64
#  10  TLDLength                   4486 non-null   int64
#  11  NoOfSubDomain               4486 non-null   int64
#  12  HasObfuscation              4486 non-null   int64
#  13  NoOfObfuscatedChar          4486 non-null   int64
#  14  ObfuscationRatio            4486 non-null   float64
#  15  NoOfLettersInURL            4486 non-null   int64
#  16  LetterRatioInURL            4486 non-null   float64
#  17  NoOfDegitsInURL             4486 non-null   int64
#  18  DegitRatioInURL             4486 non-null   float64
#  19  NoOfEqualsInURL             4486 non-null   int64
#  20  NoOfQMarkInURL              4486 non-null   int64
#  21  NoOfAmpersandInURL          4486 non-null   int64
#  22  NoOfOtherSpecialCharsInURL  4486 non-null   int64
#  23  SpacialCharRatioInURL       4486 non-null   float64
#  24  IsHTTPS                     4486 non-null   int64
#  25  LineOfCode                  4486 non-null   int64
#  26  LargestLineLength           4486 non-null   int64
#  27  HasTitle                    4486 non-null   int64
#  28  Title                       4486 non-null   int64
#  29  DomainTitleMatchScore       4486 non-null   float64
#  30  URLTitleMatchScore          4486 non-null   float64
#  31  HasFavicon                  4486 non-null   int64
#  32  Robots                      4486 non-null   int64
#  33  IsResponsive                4486 non-null   int64
#  34  NoOfURLRedirect             4486 non-null   int64
#  35  NoOfSelfRedirect            4486 non-null   int64
#  36  HasDescription              4486 non-null   int64
#  37  NoOfPopup                   4486 non-null   int64
#  38  NoOfiFrame                  4486 non-null   int64
#  39  HasExternalFormSubmit       4486 non-null   int64
#  40  HasSocialNet                4486 non-null   int64
#  41  HasSubmitButton             4486 non-null   int64
#  42  HasHiddenFields             4486 non-null   int64
#  43  HasPasswordField            4486 non-null   int64
#  44  Bank                        4486 non-null   int64
#  45  Pay                         4486 non-null   int64
#  46  Crypto                      4486 non-null   int64
#  47  HasCopyrightInfo            4486 non-null   int64
#  48  NoOfImage                   4486 non-null   int64
#  49  NoOfCSS                     4486 non-null   int64
#  50  NoOfJS                      4486 non-null   int64
#  51  NoOfSelfRef                 4485 non-null   float64
#  52  NoOfEmptyRef                4485 non-null   float64
#  53  NoOfExternalRef             4485 non-null   float64
#  54  label                       4485 non-null   float64
# dtypes: float64(14), int64(41)
# memory usage: 1.9 MB
# None

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(data.corr(), annot=False, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# drop lowly corrlated values

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# %%
# Get the correlations of all columns with the label column
correlations_with_label = correlation_matrix['label']

# %%
# Filter out columns with correlation between -0.2 and 0.2
columns_to_drop = correlations_with_label[(correlations_with_label > -0.2) & (correlations_with_label < 0.2)].index

# %%
# Drop the low-correlation columns
data = data.drop(columns=columns_to_drop)

# %%
# Display the remaining columns
print("Remaining columns after dropping low-correlation columns:")
print(data.columns)
# Out:
# Remaining columns after dropping low-correlation columns:
# Index(['URL', 'URLLength', 'Domain', 'DomainLength', 'URLSimilarityIndex',
#        'CharContinuationRate', 'URLCharProb', 'NoOfLettersInURL',
#        'LetterRatioInURL', 'NoOfDegitsInURL', 'DegitRatioInURL',
#        'NoOfOtherSpecialCharsInURL', 'SpacialCharRatioInURL', 'IsHTTPS',
#        'HasTitle', 'Title', 'DomainTitleMatchScore', 'URLTitleMatchScore',
#        'HasFavicon', 'Robots', 'IsResponsive', 'HasDescription', 'NoOfiFrame',
#        'HasSocialNet', 'HasSubmitButton', 'HasHiddenFields', 'Bank', 'Pay',
#        'HasCopyrightInfo', 'NoOfImage', 'NoOfCSS', 'NoOfJS', 'NoOfSelfRef',
#        'NoOfExternalRef', 'label'],
#       dtype='object')

# %%
# sns.pairplot(data, diag_kind='kde')
# plt.show()

# %%
for column in data.select_dtypes(include=['float64', 'int64']).columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=data[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
# Standardize features
X = data.drop(columns=['label'])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### Pre clustering PCA and t-SNE

# %%
# Step 1: Create the mask based on the original `X_scaled`
nan_mask = ~np.isnan(X_scaled).any(axis=1)  # True for rows without NaNs, False for rows with NaNs

# Step 2: Apply the mask to `X_scaled` and `data` to keep rows without NaNs in both
X_scaled = X_scaled[nan_mask]
data = data[nan_mask].reset_index(drop=True)  # Apply mask and reset index

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
plt.figure(figsize=(8, 5))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=data['label'], palette="viridis")
plt.title('Pre-Clustering PCA')
plt.show()

# %%
tsne = TSNE(n_components=2, random_state=0, perplexity=30, learning_rate=200)
X_tsne = tsne.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=data['label'], palette="viridis")
plt.title('Pre-Clustering t-SNE')
plt.show()

# %% [markdown]
# ### Dendogram

# %%
# Calculate linkage and plot dendrogram
linkage_matrix = linkage(X_scaled, method='ward')
plt.figure(figsize=(12, 5))
dendrogram(linkage_matrix)
plt.title('Dendrogram for Hierarchical Clustering')
plt.xlabel('Samples')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ### Heirarchical clustering

# %%
# Fit Agglomerative Clustering model
agg_clustering = AgglomerativeClustering(n_clusters=2, linkage='ward')
data['hierarchical_cluster'] = agg_clustering.fit_predict(X_scaled)

# %%
# Calculate Silhouette Score for Hierarchical Clustering
silhouette_score_hierarchical = silhouette_score(X_scaled, data['hierarchical_cluster'])
print(f'Silhouette Score for Hierarchical Clustering: {silhouette_score_hierarchical:.4f}')
# Out:
# Silhouette Score for Hierarchical Clustering: 0.2673

# %% [markdown]
# ### Post-Clustering t-SNE and PCA

# %%
# Plot PCA and t-SNE after clustering
plt.figure(figsize=(8, 5))
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=data['hierarchical_cluster'], palette="viridis")
plt.title('Post-Clustering PCA (Hierarchical)')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=data['hierarchical_cluster'], palette="viridis")
plt.title('Post-Clustering t-SNE (Hierarchical)')
plt.show()

# %% [markdown]
# ### Radar plot

# %%
cluster_centers = data.groupby('hierarchical_cluster').mean()
cluster_centers = cluster_centers.reset_index().melt(id_vars='hierarchical_cluster',
                                                     var_name='Feature',
                                                     value_name='Value')

fig = px.line_polar(cluster_centers,
                    r='Value',
                    theta='Feature',
                    color='hierarchical_cluster',
                    line_close=True,
                    template='plotly_dark',
                    labels={"hierarchical_cluster": "Cluster"})

fig.update_traces(fill='toself')  # Fill the radar areas
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="be4cca94-d788-4a52-b797-b33f56374bee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be4cca94-d788-4a52-b797-b33f56374bee")) {                    Plotly.newPlot(                        "be4cca94-d788-4a52-b797-b33f56374bee",                        [{"hovertemplate":"Cluster=0\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","r":[816.393098782138,40.138024357239516,1527.3355886332881,23.82679296346414,53.546486469945876,0.7536192229884979,0.051167634634641405,23.619079837618404,0.5502530446549391,3.503382949932341,0.05845602165087956,3.307848443843031,0.07875236806495264,0.4100135317997294,0.6326116373477673,1147.3132611637348,19.020751142773342,23.082319079649526,0.07036535859269283,0.04194857916102842,0.2543978349120433,0.033152909336941816,0.05615696887686062,0.004736129905277402,0.046008119079837616,0.05074424898511502,0.03924221921515562,0.04059539918809202,0.029093369418132613,0.6359945872801083,0.2787550744248985,0.7205683355886333,0.5263870094722598,0.878213802435724,0.0027063599458728013,816.393098782138],"showlegend":true,"subplot":"polar","theta":["URL","URLLength","Domain","DomainLength","URLSimilarityIndex","CharContinuationRate","URLCharProb","NoOfLettersInURL","LetterRatioInURL","NoOfDegitsInURL","DegitRatioInURL","NoOfOtherSpecialCharsInURL","SpacialCharRatioInURL","IsHTTPS","HasTitle","Title","DomainTitleMatchScore","URLTitleMatchScore","HasFavicon","Robots","IsResponsive","HasDescription","NoOfiFrame","HasSocialNet","HasSubmitButton","HasHiddenFields","Bank","Pay","HasCopyrightInfo","NoOfImage","NoOfCSS","NoOfJS","NoOfSelfRef","NoOfExternalRef","label","URL"],"type":"scatterpolar","fill":"toself"},{"hovertemplate":"Cluster=1\u003cbr\u003eValue=%{r}\u003cbr\u003eFeature=%{theta}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1","r":[2943.7203192550714,26.292317924842035,2539.09145327569,19.284669105420686,99.89691247663119,0.9320095023754572,0.06001757762055204,12.990023279015631,0.4777133355503824,0.05620219487861656,0.0023664782174925175,1.2507482540738277,0.04844762221483206,0.9993348852677086,0.9996674426338543,2012.2653807781842,74.2594934647855,74.32139808272697,0.5700033255736614,0.41902228134353176,0.8506817426005986,0.7352843365480546,2.7851679414699038,0.7961423345527103,0.6667775191220485,0.5979381443298969,0.19487861656135683,0.3654805453940805,0.8081143997339542,47.13535084802128,10.420019953441969,18.299301629531094,115.04921849018956,85.57665447289658,0.9973395410708347,2943.7203192550714],"showlegend":true,"subplot":"polar","theta":["URL","URLLength","Domain","DomainLength","URLSimilarityIndex","CharContinuationRate","URLCharProb","NoOfLettersInURL","LetterRatioInURL","NoOfDegitsInURL","DegitRatioInURL","NoOfOtherSpecialCharsInURL","SpacialCharRatioInURL","IsHTTPS","HasTitle","Title","DomainTitleMatchScore","URLTitleMatchScore","HasFavicon","Robots","IsResponsive","HasDescription","NoOfiFrame","HasSocialNet","HasSubmitButton","HasHiddenFields","Bank","Pay","HasCopyrightInfo","NoOfImage","NoOfCSS","NoOfJS","NoOfSelfRef","NoOfExternalRef","label","URL"],"type":"scatterpolar","fill":"toself"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"ov ...

# %% [markdown]
# ### Comparison with K-Means

# %%
# Fit K-Means model
kmeans = KMeans(n_clusters=2, random_state=0)
data['kmeans_cluster'] = kmeans.fit_predict(X_scaled)

# %%
# Silhouette score for K-means
silhouette_score_kmeans = silhouette_score(X_scaled, data['kmeans_cluster'])

# %%
print(f'Silhouette Score for Hierarchical Clustering: {silhouette_score_hierarchical:.4f}')
print(f'Silhouette Score for K-means: {silhouette_score_kmeans:.4f}')
print(f'Silhouette Score Difference (Hierarchical - K-Means): {silhouette_score_hierarchical - silhouette_score_kmeans:.4f}')
# Out:
# Silhouette Score for Hierarchical Clustering: 0.2673
# Silhouette Score for K-means: 0.2674
# Silhouette Score Difference (Hierarchical - K-Means): -0.0002

# %%
kmeans_centers = data.groupby('kmeans_cluster').mean()
kmeans_centers = kmeans_centers.reset_index().melt(id_vars='kmeans_cluster',
                                                   var_name='Feature',
                                                   value_name='Value')

# Step 2: Calculate average feature values for each Hierarchical cluster
hierarchical_centers = data.groupby('hierarchical_cluster').mean()
hierarchical_centers = hierarchical_centers.reset_index().melt(id_vars='hierarchical_cluster',
                                                               var_name='Feature',
                                                               value_name='Value')

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(rows=1, cols=2, subplot_titles=("K-means Clustering", "Hierarchical Clustering"),
                    specs=[[{'type': 'polar'}, {'type': 'polar'}]])

for cluster in kmeans_centers['kmeans_cluster'].unique():
    fig.add_trace(
        go.Scatterpolar(
            r=kmeans_centers[kmeans_centers['kmeans_cluster'] == cluster]['Value'],
            theta=kmeans_centers[kmeans_centers['kmeans_cluster'] == cluster]['Feature'],
            fill='toself',
            name=f"K-means Cluster {cluster}"
        ),
        row=1, col=1
    )

for cluster in hierarchical_centers['hierarchical_cluster'].unique():
    fig.add_trace(
        go.Scatterpolar(
            r=hierarchical_centers[hierarchical_centers['hierarchical_cluster'] == cluster]['Value'],
            theta=hierarchical_centers[hierarchical_centers['hierarchical_cluster'] == cluster]['Feature'],
            fill='toself',
            name=f"Hierarchical Cluster {cluster}"
        ),
        row=1, col=2
    )

fig.update_layout(
    title="Comparison of K-means and Hierarchical Clustering",
    showlegend=True,
    template="plotly_dark"
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="91778314-f947-4a1e-84a4-1271d0e17dd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91778314-f947-4a1e-84a4-1271d0e17dd3")) {                    Plotly.newPlot(                        "91778314-f947-4a1e-84a4-1271d0e17dd3",                        [{"fill":"toself","name":"K-means Cluster 0","r":[2944.9893226559893,26.265932599265934,2545.6299632966297,19.26393059726393,99.89178361171172,0.9335252794424425,0.060068155409409414,12.974307640974308,0.47770136803470137,0.05238571905238572,0.0022322322322322324,1.2439105772439105,0.04824824824824825,0.997997997997998,0.9986653319986654,2016.0613947280615,74.70747308929263,74.740839789326,0.5705705705705706,0.4194194194194194,0.8531865198531865,0.7377377377377378,2.790457123790457,0.7974641307974641,0.6676676676676677,0.5982649315982649,0.19552886219552887,0.3660326993660327,0.8108108108108109,47.23923923923924,10.444110777444111,18.359025692359026,115.26993660326994,85.79946613279947,0.995995995995996,0.9963296629963296],"theta":["URL","URLLength","Domain","DomainLength","URLSimilarityIndex","CharContinuationRate","URLCharProb","NoOfLettersInURL","LetterRatioInURL","NoOfDegitsInURL","DegitRatioInURL","NoOfOtherSpecialCharsInURL","SpacialCharRatioInURL","IsHTTPS","HasTitle","Title","DomainTitleMatchScore","URLTitleMatchScore","HasFavicon","Robots","IsResponsive","HasDescription","NoOfiFrame","HasSocialNet","HasSubmitButton","HasHiddenFields","Bank","Pay","HasCopyrightInfo","NoOfImage","NoOfCSS","NoOfJS","NoOfSelfRef","NoOfExternalRef","label","hierarchical_cluster"],"type":"scatterpolar","subplot":"polar"},{"fill":"toself","name":"K-means Cluster 1","r":[828.1337365591398,40.098118279569896,1520.9657258064517,23.838037634408604,53.86831138139112,0.7517651362439516,0.051125240680779574,23.579301075268816,0.5497896505376344,3.4879032258064515,0.058349462365591395,3.307795698924731,0.0789502688172043,0.4166666666666667,0.6370967741935484,1145.4805107526881,18.48969770767406,22.58186477545161,0.07258064516129033,0.043682795698924734,0.25336021505376344,0.03293010752688172,0.06384408602150538,0.00739247311827957,0.04838709677419355,0.053763440860215055,0.038978494623655914,0.041666666666666664,0.02889784946236559,0.739247311827957,0.29838709677419356,0.7184139784946236,0.8514784946236559,0.9986559139784946,0.012096774193548387,0.014112903225806451],"theta":["URL","URLLength","Domain","DomainLength","URLSimilarityIndex","CharContinuationRate","URLCharProb","NoOfLettersInURL","LetterRatioInURL","NoOfDegitsInURL","DegitRatioInURL","NoOfOtherSpecialCharsInURL","SpacialCharRatioInURL","IsHTTPS","HasTitle","Title","DomainTitleMatchScore","URLTitleMatchScore","HasFavicon","Robots","IsResponsive","HasDescription","NoOfiFrame","HasSocialNet","HasSubmitButton","HasHiddenFields","Bank","Pay","HasCopyrightInfo","NoOfImage","NoOfCSS","NoOfJS","NoOfSelfRef","NoOfExternalRef","label","hierarchical_cluster"],"type":"scatterpolar","subplot":"polar"},{"fill":"toself","name":"Hierarchical Cluster 0","r":[816.393098782138,40.138024357239516,1527.3355886332881,23.82679296346414,53.546486469945876,0.7536192229884979,0.051167634634641405,23.619079837618404,0.5502530446549391,3.503382949932341,0.05845602165087956,3.307848443843031,0.07875236806495264,0.4100135317997294,0.6326116373477673,1147.3132611637348,19.020751142773342,23.082319079649526,0.07036535859269283,0.04194857916102842,0.2543978349120433,0.033152909336941816,0.05615696887686062,0.004736129905277402,0.046008119079837616,0.05074424898511502,0.03924221921515562,0.04059539918809202,0.029093369418132613,0.6359945872801083,0.2787550744248985,0.7205683355886333,0.5263870094722598,0.878213802435724,0.0027063599458728013,0.9925575101488497],"theta ...
